# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('zomato_dataset.csv')
data
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
data.shape
# Out:
# (123657, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123657 entries, 0 to 123656
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Restaurant Name  123657 non-null  object
#  1   Dining Rating    91421 non-null   float64
#  2   Delivery Rating  122377 non-null  float64
#  3   Dining Votes     123657 non-null  int64
#  4   Delivery Votes   123657 non-null  int64
#  5   Cuisine          123657 non-null  object
#  6   Place Name       123657 non-null  object
#  7   City             123657 non-null  object
#  8   Item Name        123657 non-null  object
#  9   Best Seller      27942 non-null   object
#  10  Votes            123657 non-null  int64
#  11  Prices           123657 non-null  float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 11.3+ MB

# %%
data.describe()
# Out:
#        Dining Rating  Delivery Rating   Dining Votes  Delivery Votes  \
# count   91421.000000    122377.000000  123657.000000   123657.000000
# mean        3.822264         3.963184     152.729858      115.763725
# std         0.408693         0.245900     232.214061      243.970828
# min         2.500000         2.500000       0.000000        0.000000
# 25%         3.600000         3.800000       0.000000        0.000000
# 50%         3.900000         4.000000      30.000000        0.000000
# 75%         4.100000         4.100000     217.000000       23.000000
# max         4.800000         4.600000     997.000000      983.000000
#
#                Votes         Prices
# count  123657.000000  123657.000000
# mean       24.666772     241.378399
# std       125.236009     192.830713
# min         0.000000       0.950000
# 25%         0.000000     130.000000
# 50%         0.000000     208.570000
# 75%        15.000000     299.000000
# max      9750.000000   12024.000000

# %%
data.isna().sum()
# Out:
# Restaurant Name        0
# Dining Rating      32236
# Delivery Rating     1280
# Dining Votes           0
# Delivery Votes         0
# Cuisine                0
# Place Name             0
# City                   0
# Item Name              0
# Best Seller        95715
# Votes                  0
# Prices                 0
# dtype: int64

# %% [markdown]
# percentage of misssing values in Dining Rating , Delivery Rating and Best Seller

# %%
print('Perecentage of missing values in Dining Rating is :-',data['Dining Rating'].isna().sum()/data.shape[0]*100)
# Out:
# Perecentage of missing values in Dining Rating is :- 26.068884090670156

# %%
print('Perecentage of missing values in Delivery Rating is :-',data['Delivery Rating'].isna().sum()/data.shape[0]*100)
# Out:
# Perecentage of missing values in Delivery Rating is :- 1.0351213437168942

# %%
print('Perecentage of missing values in Best Seller is :-',data['Best Seller'].isna().sum()/data.shape[0]*100)
# Out:
# Perecentage of missing values in Best Seller is :- 77.40362454208011

# %% [markdown]
# We will drop Best Seller column because the missing values is more than 50 percent.

# %%
data = data.drop(data.columns[9] , axis=1)
data
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %%
mean_value = data['Delivery Rating'].mean()
data['Delivary rating'] = data['Delivery Rating'].fillna(mean_value)

# %%
new_mean = data['Dining Rating'].mean()
data['Dining rating'] = data['Dining Rating'].fillna(new_mean)

# %%
data
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %% [markdown]
# As the columns containing missing values are numerical data and that too both are ratings so we will fill the na values with the mean of the columns

# %%
data = data.drop(['Dining Rating','Delivery Rating'],axis=1)

# %%
data
# Out:
#               Restaurant Name  Dining Votes  Delivery Votes   Cuisine   \
# 0                  Doner King            39               0  Fast Food
# 1                  Doner King            39               0  Fast Food
# 2                  Doner King            39               0  Fast Food
# 3                  Doner King            39               0  Fast Food
# 4                  Doner King            39               0  Fast Food
# ...                       ...           ...             ...        ...
# 123652  Ariena Boutique Hotel            13             523      Pizza
# 123653  Ariena Boutique Hotel            13             523      Pizza
# 123654  Ariena Boutique Hotel            13             523      Pizza
# 123655  Ariena Boutique Hotel            13             523      Pizza
# 123656  Ariena Boutique Hotel            13             523      Pizza
#
#        Place Name        City                 Item Name  Votes  Prices  \
# ...

# %%
data.isna().sum()
# Out:
# Restaurant Name    0
# Dining Votes       0
# Delivery Votes     0
# Cuisine            0
# Place Name         0
# City               0
# Item Name          0
# Votes              0
# Prices             0
# Delivary rating    0
# Dining rating      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 26322

# %%
print('Perecentage of duplicate values in Data is :-',data.duplicated().sum()/data.shape[0]*100)
# Out:
# Perecentage of duplicate values in Data is :- 21.286300007278196

# %%
data = data.drop_duplicates(keep='first')

# %%
data
# Out:
#               Restaurant Name  Dining Votes  Delivery Votes   Cuisine   \
# 0                  Doner King            39               0  Fast Food
# 1                  Doner King            39               0  Fast Food
# 2                  Doner King            39               0  Fast Food
# 3                  Doner King            39               0  Fast Food
# 4                  Doner King            39               0  Fast Food
# ...                       ...           ...             ...        ...
# 123630  Ariena Boutique Hotel            13             523      Pizza
# 123631  Ariena Boutique Hotel            13             523      Pizza
# 123632  Ariena Boutique Hotel            13             523      Pizza
# 123633  Ariena Boutique Hotel            13             523      Pizza
# 123634  Ariena Boutique Hotel            13             523      Pizza
#
#        Place Name        City                 Item Name  Votes  Prices  \
# ...

# %%
data['Restaurant Name'].value_counts()
# Out:
# McDonald's                         1448
# FreshMenu                           992
# Burger King                         934
# Pizza Hut                           812
# Domino's Pizza                      755
#                                    ...
# Lalla Biryani - Since 1985            4
# Al - Hamoor Arabian Restaurant        3
# Payasam Kada - Taste Trees            3
# Sukanta                               3
# Salkara Xpress By Paragon Group       3
# Name: Restaurant Name, Length: 826, dtype: int64

# %%
data['Restaurant Name'].unique()
# Out:
# array(['Doner King', 'Taco Bell', 'BrownBear', 'Crystal Restaurant & Bar',
#        'Siddique Kabab Centre', 'Shah Ghouse Special Shawarma',
#        'Taj Mahal - Taj Mahal Hotel', 'Burger King', 'Papadams Blue',
#        'Ovenstory Pizza', 'Italian Pizzeria', 'Al Rabea Mandi House',
#        'Govind Dosa', 'Universal Al Mataam Mandi Kebab & Biryani',
#        'The Thickshake Factory', 'Platform 65', 'Food Track',
#        'The Burger Club', 'Acme Candy Food', 'MS Bakery & Sweets',
#        'New Grand Restaurant & Bakery', 'Al - Hamoor Arabian Restaurant',
#        "McDonald's", 'Capital Multi Cuisine Restaurant',
#        'Mayur Pan House', 'Yashwanth Pizza Den', 'Hotel Nayaab',
#        'Red Bucket Biryani', 'Hotel Shadab', 'Mughal Restaurant',
#        'UBQ by Barbeque Nation', 'Santosh Dhaba', 'Tipsy Topsy Bakery',
#        'Shah Ghouse Hotel & Restaurant', "La Pino'z Pizza", 'Istanbul',
#        'Iqbal Cafe', 'Barbeque Nation',
# ...

# %%
data['Delivery Votes'].value_counts()
# Out:
# 0      71103
# 183      712
# 3        512
# 662      456
# 405      374
#        ...
# 478       11
# 471        9
# 198        8
# 169        8
# 217        4
# Name: Delivery Votes, Length: 263, dtype: int64

# %%
data['Dining Votes'].value_counts()
# Out:
# 0      33414
# 2       1384
# 4       1108
# 1        871
# 848      773
#        ...
# 368       20
# 482       18
# 245       16
# 37         7
# 373        5
# Name: Dining Votes, Length: 294, dtype: int64

# %%
data['Cuisine '].value_counts()
# Out:
# Beverages        31650
# Pizza            11829
# Fast Food         8933
# Desserts          8869
# Chinese           4873
# Sichuan           4680
# Biryani           3263
# Shake             2689
# North Indian      2278
# Street Food       2236
# Rolls             1521
# South Indian      1404
# Seafood           1237
# Mughlai            924
# Ice Cream          908
# Bakery             868
# Momos              821
# BBQ                682
# Kebab              621
# Gujarati           557
# Burger             548
# Continental        514
# Juices             512
# Sandwich           498
# Mithai             466
# Coffee             424
# Mandi              353
# Kerala             308
# American           285
# Salad              279
# Maharashtrian      277
# Hyderabadi         276
# Pasta              244
# Kathiyawadi        218
# Lucknowi           185
# Healthy Food       174
# Mexican            166
# Italian            159
# Rajasthani         155
# Shawarma           147
# ...

# %%
location_counts = data['City'].value_counts().head(10)
plt.figure(figsize=(8,6))
plt.pie(location_counts , labels=location_counts.index,autopct = '%.2f%%')
plt.title('Top 10 Cities with Most Number of Restaurants',fontsize=14)
plt.show()

# %%
data['Average Rating'] = (data['Delivary rating'] + data['Dining rating'])/2

# %%
data
# Out:
#               Restaurant Name  Dining Votes  Delivery Votes   Cuisine   \
# 0                  Doner King            39               0  Fast Food
# 1                  Doner King            39               0  Fast Food
# 2                  Doner King            39               0  Fast Food
# 3                  Doner King            39               0  Fast Food
# 4                  Doner King            39               0  Fast Food
# ...                       ...           ...             ...        ...
# 123630  Ariena Boutique Hotel            13             523      Pizza
# 123631  Ariena Boutique Hotel            13             523      Pizza
# 123632  Ariena Boutique Hotel            13             523      Pizza
# 123633  Ariena Boutique Hotel            13             523      Pizza
# 123634  Ariena Boutique Hotel            13             523      Pizza
#
#        Place Name        City                 Item Name  Votes  Prices  \
# ...

# %%
data.to_csv('data_new.csv',index=False)

# %%
item_name = data['Item Name'].value_counts().head(5)
colors = ['red','blue','green','orange','pink']
plt.figure(figsize=(10,8))
plt.bar( item_name.index,item_name,color = colors)
plt.title('Top 5 Most ordered items ',fontsize=14)
plt.xlabel('Ordered Items ')
plt.ylabel('Frequency ')
plt.show()

# %%
x = data['Average Rating']
y= data['Prices']
plt.figure(figsize=(8,6))
plt.scatter(y,x)
plt.show()

# %%
X=data.drop(['Prices'],axis=1)
Y = data['Prices']
X.corrwith(Y).plot.bar(
        figsize = (16, 4), title = "Correlation", fontsize = 15,
        rot = 90, grid = True)
# Out:
# <Axes: title={'center': 'Correlation'}>

# %% [markdown]
# Correlation Between prices and other attributes

# %%
restaurent_name = data['Restaurant Name'].value_counts().head(5)
plt.figure(figsize=(10,8))
colors = ['red','blue','green','orange','pink']
plt.bar(restaurent_name.index , restaurent_name,color=colors)
plt.xlabel('Count')
plt.ylabel('Name')
plt.title('Most number of Restaurents',fontsize=14)
plt.show()
